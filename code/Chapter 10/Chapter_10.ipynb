# %% [markdown]
# <a href="https://colab.research.google.com/github/nceder/qpb4e/blob/main/code/Chapter%2010/Chapter_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 Modules and scoping rules
#
# # 10.2 A first module

# %%
# %%writefile mymath.py
"""mymath - our example math module"""
pi = 3.14159
def area(r):
    """area(r): return the area of a circle with radius r."""
    return(pi * r * r)
# Out:
# Writing mymath.py

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
area(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 area(2)
#
# NameError: name 'area' is not defined

# %%
import mymath
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import mymath
# ----> 2 pi
#
# NameError: name 'pi' is not defined

# %%
mymath.pi
# Out:
# 3.14159

# %%
mymath.area(2)
# Out:
# 12.56636

# %%
mymath.__doc__
# Out:
# 'mymath - our example math module'

# %%
mymath.area.__doc__
# Out:
# 'area(r): return the area of a circle with radius r.'

# %%
from mymath import pi
pi
# Out:
# 3.14159

# %%
area(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 area(2)
#
# NameError: name 'area' is not defined

# %%
import mymath, importlib
importlib.reload(mymath)
# Out:
# <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>

# %% [markdown]
# # 10.3 The import statement

# %%
from mymath import *

# %% [markdown]
# # 10.4 The module search path

# %%
import sys
sys.path
# Out:
# ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#  '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#  '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#  '',
#  '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages']

# %% [markdown]
# # 10.5 Private names in modules

# %%
# %%writefile modtest.py
"""modtest: our test module"""
def f(x):
    return x
def _g(x):
    return x
a = 4
_b = 2
# Out:
# Writing modtest.py

# %%
from modtest import *
f(3)
# Out:
# 3

# %%
_g(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 _g(3)
#
# NameError: name '_g' is not defined

# %%
a
# Out:
# 4

# %%
_b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 _b
#
# NameError: name '_b' is not defined

# %%
import modtest
modtest._b
# Out:
# 2

# %%
from modtest import _g
_g(5)
# Out:
# 5

# %% [markdown]
# # 10.6 Library and third-party modules

# %% [markdown]
# ### Quick Check: Modules
# Suppose that you have a module called `new_math` that contains a function called `new_divide`. What are the ways that you might import and then use that function? What are the pros and cons of each method?
#
# ```python
# import new_math
# new_math.new_divide(...)
# ```
# **This solution is often preferred because there won’t be a clash between any identifiers in new_module and the importing namespace. This solution is less convenient to type, however.**
#
# ```python
# from new_math import new_divide
# new_divide(...)
# ```
# **This version is more convenient to use but increases the chance of name clashes between identifiers in the module and the importing namespace.**
#
# Suppose that the new_math module contains a function called `_helper_mat-h()`. How will the underscore character affect the way that `_helper_math()` is imported?
#
# **It won’t be imported if you use `from new_math import*`**

# %% [markdown]
# # 10.7 Python scoping rules and namespaces

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()'],
#  '_oh': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5},
#  '_dh': [PosixPath('/home/davidd/2025/qpb4e/code/Chapter 10')],
#  'In': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()'],
#  'Out': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f28884dbe00>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': 5,
#  '__': 2,
#  '___': 4,
#  '__vsc_ipynb_file__': '/home/davidd/2025/qpb4e/code/Chapter 10/Chapter_10.ipynb',
#  '_i': 'from modtest import _g\n_g(5)',
#  '_ii': 'import modtest\nmodtest._b',
#  '_iii': '_b',
#  '_i1': '%%writefile mymath.py\n"""mymath - our example math module"""\npi = 3.14159\ndef area(r):\n    """area(r): return the area of a circle with radius r."""\n    return(pi * r * r)',
#  '_i2': 'pi',
#  '_i3': 'area(2)',
#  '_i4': 'import mymath\npi',
#  'mymath': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i5': 'mymath.pi',
#  '_5': 3.14159,
#  '_i6': 'mymath.area(2)',
#  '_6': 12.56636,
#  '_i7': 'mymath.__doc__',
#  '_7': 'mymath - our example math module',
#  '_i8': 'mymath.area.__doc__',
#  '_8': 'area(r): return the area of a circle with radius r.',
#  '_i9': 'from mymath import pi\npi',
#  'pi': 3.14159,
#  '_9': 3.14159,
#  '_i10': 'area(2)',
#  '_i11': 'import mymath, importlib\nimportlib.reload(mymath)',
#  'importlib': <module 'importlib' from '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/importlib/__init__.py'>,
#  '_11': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i12': 'from mymath import *',
#  'area': <function mymath.area(r)>,
#  '_i13': 'import sys\nsys.path',
#  'sys': <module 'sys' (built-in)>,
#  '_13': ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#   '',
#   '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#  '_i14': '%%writefile modtest.py\n"""modtest: our test module"""\ndef f(x):\n    return x\ndef _g(x):\n    return x\na = 4\n_b = 2',
#  '_i15': 'from modtest import *\nf(3)',
#  'f': <function modtest.f(x)>,
#  'a': 4,
#  '_15': 3,
#  '_i16': '_g(3)',
#  '_i17': 'a',
#  '_17': 4,
#  '_i18': '_b',
#  '_i19': 'import modtest\nmodtest._b',
#  'modtest': <module 'modtest' from '/home/davidd/2025/qpb4e/code/Chapter 10/modtest.py'>,
#  '_19': 2,
#  '_i20': 'from modtest import _g\n_g(5)',
#  '_g': <function modtest._g(x)>,
#  '_20': 5,
#  '_i21': 'locals()'}

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()',
#   'globals()'],
#  '_oh': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5,
#   21: {...}},
#  '_dh': [PosixPath('/home/davidd/2025/qpb4e/code/Chapter 10')],
#  'In': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()',
#   'globals()'],
#  'Out': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5,
#   21: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f28884dbe00>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': 5,
#  '___': 2,
#  '__vsc_ipynb_file__': '/home/davidd/2025/qpb4e/code/Chapter 10/Chapter_10.ipynb',
#  '_i': 'locals()',
#  '_ii': 'from modtest import _g\n_g(5)',
#  '_iii': 'import modtest\nmodtest._b',
#  '_i1': '%%writefile mymath.py\n"""mymath - our example math module"""\npi = 3.14159\ndef area(r):\n    """area(r): return the area of a circle with radius r."""\n    return(pi * r * r)',
#  '_i2': 'pi',
#  '_i3': 'area(2)',
#  '_i4': 'import mymath\npi',
#  'mymath': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i5': 'mymath.pi',
#  '_5': 3.14159,
#  '_i6': 'mymath.area(2)',
#  '_6': 12.56636,
#  '_i7': 'mymath.__doc__',
#  '_7': 'mymath - our example math module',
#  '_i8': 'mymath.area.__doc__',
#  '_8': 'area(r): return the area of a circle with radius r.',
#  '_i9': 'from mymath import pi\npi',
#  'pi': 3.14159,
#  '_9': 3.14159,
#  '_i10': 'area(2)',
#  '_i11': 'import mymath, importlib\nimportlib.reload(mymath)',
#  'importlib': <module 'importlib' from '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/importlib/__init__.py'>,
#  '_11': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i12': 'from mymath import *',
#  'area': <function mymath.area(r)>,
#  '_i13': 'import sys\nsys.path',
#  'sys': <module 'sys' (built-in)>,
#  '_13': ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#   '',
#   '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#  '_i14': '%%writefile modtest.py\n"""modtest: our test module"""\ndef f(x):\n    return x\ndef _g(x):\n    return x\na = 4\n_b = 2',
#  '_i15': 'from modtest import *\nf(3)',
#  'f': <function modtest.f(x)>,
#  'a': 4,
#  '_15': 3,
#  '_i16': '_g(3)',
#  '_i17': 'a',
#  '_17': 4,
#  '_i18': '_b',
#  '_i19': 'import modtest\nmodtest._b',
#  'modtest': <module 'modtest' from '/home/davidd/2025/qpb4e/code/Chapter 10/modtest.py'>,
#  '_19': 2,
#  '_i20': 'from modtest import _g\n_g(5)',
#  '_g': <function modtest._g(x)>,
#  '_20': 5,
#  '_i21': 'locals()',
#  '_21': {...},
#  '_i22': 'globals()'}

# %%
z = 2
import math
from cmath import cos
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()',
#   'globals()',
#   'z = 2\nimport math\nfrom cmath import cos\nglobals()'],
#  '_oh': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5,
#   21: {...},
#   22: {...}},
#  '_dh': [PosixPath('/home/davidd/2025/qpb4e/code/Chapter 10')],
#  'In': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()',
#   'globals()',
#   'z = 2\nimport math\nfrom cmath import cos\nglobals()'],
#  'Out': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5,
#   21: {...},
#   22: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f28884dbe00>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': {...},
#  '___': 5,
#  '__vsc_ipynb_file__': '/home/davidd/2025/qpb4e/code/Chapter 10/Chapter_10.ipynb',
#  '_i': 'globals()',
#  '_ii': 'locals()',
#  '_iii': 'from modtest import _g\n_g(5)',
#  '_i1': '%%writefile mymath.py\n"""mymath - our example math module"""\npi = 3.14159\ndef area(r):\n    """area(r): return the area of a circle with radius r."""\n    return(pi * r * r)',
#  '_i2': 'pi',
#  '_i3': 'area(2)',
#  '_i4': 'import mymath\npi',
#  'mymath': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i5': 'mymath.pi',
#  '_5': 3.14159,
#  '_i6': 'mymath.area(2)',
#  '_6': 12.56636,
#  '_i7': 'mymath.__doc__',
#  '_7': 'mymath - our example math module',
#  '_i8': 'mymath.area.__doc__',
#  '_8': 'area(r): return the area of a circle with radius r.',
#  '_i9': 'from mymath import pi\npi',
#  'pi': 3.14159,
#  '_9': 3.14159,
#  '_i10': 'area(2)',
#  '_i11': 'import mymath, importlib\nimportlib.reload(mymath)',
#  'importlib': <module 'importlib' from '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/importlib/__init__.py'>,
#  '_11': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i12': 'from mymath import *',
#  'area': <function mymath.area(r)>,
#  '_i13': 'import sys\nsys.path',
#  'sys': <module 'sys' (built-in)>,
#  '_13': ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#   '',
#   '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#  '_i14': '%%writefile modtest.py\n"""modtest: our test module"""\ndef f(x):\n    return x\ndef _g(x):\n    return x\na = 4\n_b = 2',
#  '_i15': 'from modtest import *\nf(3)',
#  'f': <function modtest.f(x)>,
#  'a': 4,
#  '_15': 3,
#  '_i16': '_g(3)',
#  '_i17': 'a',
#  '_17': 4,
#  '_i18': '_b',
#  '_i19': 'import modtest\nmodtest._b',
#  'modtest': <module 'modtest' from '/home/davidd/2025/qpb4e/code/Chapter 10/modtest.py'>,
#  '_19': 2,
#  '_i20': 'from modtest import _g\n_g(5)',
#  '_g': <function modtest._g(x)>,
#  '_20': 5,
#  '_i21': 'locals()',
#  '_21': {...},
#  '_i22': 'globals()',
#  '_22': {...},
#  '_i23': 'z = 2\nimport math\nfrom cmath import cos\nglobals()',
#  'z': 2,
#  'math': <module 'math' (built-in)>,
#  'cos': <function cmath.cos(z, /)>}

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()',
#   'globals()',
#   'z = 2\nimport math\nfrom cmath import cos\nglobals()',
#   'locals()'],
#  '_oh': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5,
#   21: {...},
#   22: {...},
#   23: {...}},
#  '_dh': [PosixPath('/home/davidd/2025/qpb4e/code/Chapter 10')],
#  'In': ['',
#   'get_ipython().run_cell_magic(\'writefile\', \'mymath.py\', \'"""mymath - our example math module"""\\npi = 3.14159\\ndef area(r):\\n    """area(r): return the area of a circle with radius r."""\\n    return(pi * r * r)\\n\')',
#   'pi',
#   'area(2)',
#   'import mymath\npi',
#   'mymath.pi',
#   'mymath.area(2)',
#   'mymath.__doc__',
#   'mymath.area.__doc__',
#   'from mymath import pi\npi',
#   'area(2)',
#   'import mymath, importlib\nimportlib.reload(mymath)',
#   'from mymath import *',
#   'import sys\nsys.path',
#   'get_ipython().run_cell_magic(\'writefile\', \'modtest.py\', \'"""modtest: our test module"""\\ndef f(x):\\n    return x\\ndef _g(x):\\n    return x\\na = 4\\n_b = 2\\n\')',
#   'from modtest import *\nf(3)',
#   '_g(3)',
#   'a',
#   '_b',
#   'import modtest\nmodtest._b',
#   'from modtest import _g\n_g(5)',
#   'locals()',
#   'globals()',
#   'z = 2\nimport math\nfrom cmath import cos\nglobals()',
#   'locals()'],
#  'Out': {5: 3.14159,
#   6: 12.56636,
#   7: 'mymath - our example math module',
#   8: 'area(r): return the area of a circle with radius r.',
#   9: 3.14159,
#   11: <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#   13: ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#    '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#    '',
#    '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#   15: 3,
#   17: 4,
#   19: 2,
#   20: 5,
#   21: {...},
#   22: {...},
#   23: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f28884dbe00>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f2888386510>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': {...},
#  '___': {...},
#  '__vsc_ipynb_file__': '/home/davidd/2025/qpb4e/code/Chapter 10/Chapter_10.ipynb',
#  '_i': 'z = 2\nimport math\nfrom cmath import cos\nglobals()',
#  '_ii': 'globals()',
#  '_iii': 'locals()',
#  '_i1': '%%writefile mymath.py\n"""mymath - our example math module"""\npi = 3.14159\ndef area(r):\n    """area(r): return the area of a circle with radius r."""\n    return(pi * r * r)',
#  '_i2': 'pi',
#  '_i3': 'area(2)',
#  '_i4': 'import mymath\npi',
#  'mymath': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i5': 'mymath.pi',
#  '_5': 3.14159,
#  '_i6': 'mymath.area(2)',
#  '_6': 12.56636,
#  '_i7': 'mymath.__doc__',
#  '_7': 'mymath - our example math module',
#  '_i8': 'mymath.area.__doc__',
#  '_8': 'area(r): return the area of a circle with radius r.',
#  '_i9': 'from mymath import pi\npi',
#  'pi': 3.14159,
#  '_9': 3.14159,
#  '_i10': 'area(2)',
#  '_i11': 'import mymath, importlib\nimportlib.reload(mymath)',
#  'importlib': <module 'importlib' from '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/importlib/__init__.py'>,
#  '_11': <module 'mymath' from '/home/davidd/2025/qpb4e/code/Chapter 10/mymath.py'>,
#  '_i12': 'from mymath import *',
#  'area': <function mymath.area(r)>,
#  '_i13': 'import sys\nsys.path',
#  'sys': <module 'sys' (built-in)>,
#  '_13': ['/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python313.zip',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13',
#   '/home/davidd/.local/share/uv/python/cpython-3.13.1-linux-x86_64-gnu/lib/python3.13/lib-dynload',
#   '',
#   '/home/davidd/2025/qpb4e/.venv/lib/python3.13/site-packages'],
#  '_i14': '%%writefile modtest.py\n"""modtest: our test module"""\ndef f(x):\n    return x\ndef _g(x):\n    return x\na = 4\n_b = 2',
#  '_i15': 'from modtest import *\nf(3)',
#  'f': <function modtest.f(x)>,
#  'a': 4,
#  '_15': 3,
#  '_i16': '_g(3)',
#  '_i17': 'a',
#  '_17': 4,
#  '_i18': '_b',
#  '_i19': 'import modtest\nmodtest._b',
#  'modtest': <module 'modtest' from '/home/davidd/2025/qpb4e/code/Chapter 10/modtest.py'>,
#  '_19': 2,
#  '_i20': 'from modtest import _g\n_g(5)',
#  '_g': <function modtest._g(x)>,
#  '_20': 5,
#  '_i21': 'locals()',
#  '_21': {...},
#  '_i22': 'globals()',
#  '_22': {...},
#  '_i23': 'z = 2\nimport math\nfrom cmath import cos\nglobals()',
#  'z': 2,
#  'math': <module 'math' (built-in)>,
#  'cos': <function cmath.cos(z, /)>,
#  '_23': {...},
#  '_i24': 'locals()'}

# %%
math.ceil(3.4)
# Out:
# 4

# %%
del z, math, cos

# %%
math.ceil(3.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 math.ceil(3.4)
#
# NameError: name 'math' is not defined

# %%
import math
math.ceil(3.4)
# Out:
# 4

# %%
def f(x):

    print("Entry local: ", locals())
    y = x
    print("Exit local: ", locals())

z = 2

f(z)
# Out:
# Entry local:  {'x': 2}
# Exit local:  {'x': 2, 'y': 2}

# %%
# %%writefile scopetest.py
"""scopetest: our scope test module"""
v = 6
def f(x):
    """f: scope test function"""
    print("global: ", list(globals().keys()))
    print("entry local:", locals())
    y = x
    w = v
    print("exit local:", locals().keys())
# Out:
# Writing scopetest.py

# %%
import scopetest
z = 2
scopetest.f(z)
# Out:
# global:  ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__file__', '__cached__', '__builtins__', 'v', 'f']
# entry local: {'x': 2}
# exit local: dict_keys(['x', 'y', 'w'])

# %% [markdown]
# ## 10.7.1 The built-in namespace

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'PythonFinalizationError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'ZeroDivisionError',
#  '_IncompleteInputError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'aiter',
#  'all',
#  'anext',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'execfile',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'runfile',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
print(max.__doc__)
# Out:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more positional arguments, return the largest argument.

# %%
list("Peyto Lake")
# Out:
# ['P', 'e', 'y', 't', 'o', ' ', 'L', 'a', 'k', 'e']

# %%
list = [1, 3, 5, 7]
list("Peyto Lake")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 list = [1, 3, 5, 7]
# ----> 2 list("Peyto Lake")
#
# TypeError: 'list' object is not callable

# %%
import mymath
mymath = mymath.area
mymath.pi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 3
#       1 import mymath
#       2 mymath = mymath.area
# ----> 3 mymath.pi
#
# AttributeError: 'function' object has no attribute 'pi'

# %%
del list
list("Peyto Lake")
# Out:
# ['P', 'e', 'y', 't', 'o', ' ', 'L', 'a', 'k', 'e']

# %%
import mymath
mymath.pi
# Out:
# 3.14159

# %%
x1 = 6
xl = x1 - 2
x1
# Out:
# 6

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_13',
#  '_15',
#  '_17',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_28',
#  '_32',
#  '_34',
#  '_37',
#  '_38',
#  '_39',
#  '_5',
#  '_6',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_g',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'area',
#  'exit',
#  'f',
#  'get_ipython',
#  'importlib',
#  'math',
#  'modtest',
#  'mymath',
#  'open',
#  'pi',
#  'quit',
#  'scopetest',
#  'sys',
#  'x1',
#  'xl',
#  'z']

# %% [markdown]
# ### Quick Check: Namespaces and scope
# Consider a variable width that's in the module `make_window.py`. In which of the following contexts is width in scope?:
#
#  1. within the module itself
#  2. inside the `resize()` function in the module
#  3. within the script that imported the `make_window.py` module
#
#  **A and B but not C**

# %% [markdown]
# # Lab 10: Create a module
# Package the functions created at the end of chapter 9 as a standalone module. Although you can include code to run the module as the main program, the goal should be for the functions to be completely usable from another script. To test, create a new Jupyter notebook and write the code to load and use the module to get the same results as the code in Chapter 9.

# %%
# !wget https://raw.githubusercontent.com/nceder/qpb4e/main/code/Chapter%2006/moby_01.txt &> null  && echo Downloaded
# Out:
# Downloaded

# %%
with open("text_processing_author.py", "w") as f:
    f.write(r'''
# Author's version
import string
punct = str.maketrans('', '', string.punctuation)

def clean_line(line):
    """changes case and removes punctuation"""
    # make all one case
    cleaned_line = line.lower()

    # remove punctuation
    cleaned_line = cleaned_line.translate(punct)
    return cleaned_line


def get_words(line):
    """splits line into words, and rejoins with newlines"""
    words = line.split()
    return "\n".join(words) + "\n"


def count_words(words):
    """takes list of cleaned words, returns count dictionary"""
    word_count = {}
    for word in words:
        count = word_count.setdefault(word, 0)
        word_count[word] += 1
    return word_count


def word_stats(word_count):
    """Takes word count dictionary and returns top and bottom five entries"""
    word_list = list(word_count.items())
    word_list.sort(key=lambda x: x[1])
    least_common = word_list[:5]
    most_common = word_list[-1:-6:-1]
    return most_common, least_common
'''
    )

import text_processing_author


with open("moby_01.txt") as infile, open("moby_01_clean.txt", "w") as outfile:
    for line in infile:
        cleaned_line = text_processing_author.clean_line(line)

        cleaned_words = text_processing_author.get_words(cleaned_line)

        # write all words for line
        outfile.write(cleaned_words)

moby_words = []
with open('moby_01_clean.txt') as infile:
    for word in infile:
        if word.strip():
            moby_words.append(word.strip())


word_count = text_processing_author.count_words(moby_words)

most, least = text_processing_author.word_stats(word_count)
print("Most common words:")
for word in most:
    print(word)
print("\nLeast common words:")
for word in least:
    print(word)
# Out:
# Most common words:
# ('the', 14)
# ('i', 9)
# ('and', 9)
# ('of', 8)
# ('is', 7)
#
# Least common words:
# ('call', 1)
# ('ishmael', 1)
# ('years', 1)
# ('ago', 1)
# ('never', 1)

# %%
# refactored code from Copilot
import string

def clean_line(line):
    # Convert the line to lowercase
    line = line.lower()

    # Remove punctuation from the line
    line = line.translate(str.maketrans('', '', string.punctuation))

    return line

def write_words_to_file(words, output_file):
    # Write each word to the output file
    for word in words:
        output_file.write(word + '\n')

def count_word_occurrences(words):
    # Count the occurrences of each word using a dictionary
    word_counts = {}
    for word in words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1

    return word_counts

def print_common_words(word_counts, n):
    # Sort the word counts in descending order
    sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

    # Print the n most common words and their occurrences
    print(f"{n} most common words:")
    for word, count in sorted_word_counts[:n]:
        print(f"{word}: {count}")

def print_least_common_words(word_counts, n):
    # Sort the word counts in descending order
    sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

    # Print the n least common words and their occurrences
    print(f"{n} least common words:")
    for word, count in sorted_word_counts[-n:]:
        print(f"{word}: {count}")

def process_file(input_file_path, output_file_path):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Open the output file for writing
        with open(output_file_path, 'w') as output_file:
            # Iterate over each line in the input file
            for line in input_file:
                # Clean the line
                cleaned_line = clean_line(line)

                # Split the line into words
                words = cleaned_line.split()

                # Write the words to the output file
                write_words_to_file(words, output_file)

def main():
    input_file_path = 'moby_01.txt'
    output_file_path = 'moby_01_clean.txt'

    # Process the file
    process_file(input_file_path, output_file_path)

    # Open the file
    with open(output_file_path, 'r') as file:
        # Read the file content
        content = file.read()

    # Split the content into words
    words = content.split()

    # Count word occurrences
    word_counts = count_word_occurrences(words)

    # Print the five most common words and their occurrences
    print_common_words(word_counts, 5)

    # Print the five least common words and their occurrences
    print_least_common_words(word_counts, 5)

if __name__ == "__main__":
    main()
# Out:
# 5 most common words:
# the: 14
# and: 9
# i: 9
# of: 8
# is: 7
# 5 least common words:
# land: 1
# look: 1
# at: 1
# crowds: 1
# watergazers: 1

# %%
# Generated by colaboratory
# prompt: Package the functions in the cell above as a standalone module so that
#         the module can be used by other code. Then write the code to use the
#         module to achieve the same result as the cell above.

# Save the functions as a module named "text_processing.py"
# with open("text_processing.py", "w") as f:
#     f.write(r"""
# import string
# def clean_line(line):
#     # Convert the line to lowercase
#     line = line.lower()

#     # Remove punctuation from the line
#     line = line.translate(str.maketrans('', '', string.punctuation))

#     return line

# def write_words_to_file(words, output_file):
#     # Write each word to the output file
#     for word in words:
#         output_file.write(word + '\n')

# def count_word_occurrences(words):
#     # Count the occurrences of each word using a dictionary
#     word_counts = {}
#     for word in words:
#         if word in word_counts:
#             word_counts[word] += 1
#         else:
#             word_counts[word] = 1

#     return word_counts

# def print_common_words(word_counts, n):
#     # Sort the word counts in descending order
#     sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

#     # Print the n most common words and their occurrences
#     print(f"{n} most common words:")
#     for word, count in sorted_word_counts[:n]:
#         print(f"{word}: {count}")

# def print_least_common_words(word_counts, n):
#     # Sort the word counts in descending order
#     sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

#     # Print the n least common words and their occurrences
#     print(f"{n} least common words:")
#     for word, count in sorted_word_counts[-n:]:
#         print(f"{word}: {count}")

# def process_file(input_file_path, output_file_path):
#     # Open the input file for reading
#     with open(input_file_path, 'r') as input_file:
#         # Open the output file for writing
#         with open(output_file_path, 'w') as output_file:
#             # Iterate over each line in the input file
#             for line in input_file:
#                 # Clean the line
#                 cleaned_line = clean_line(line)

#                 # Split the line into words
#                 words = cleaned_line.split()

#                 # Write the words to the output file
#                 write_words_to_file(words, output_file)
# """)

# Use the module
import importlib, text_processing
importlib.reload(text_processing)
#import text_processing

input_file_path = 'moby_01.txt'
output_file_path = 'moby_01_clean.txt'

# Process the file
text_processing.process_file(input_file_path, output_file_path)

# Open the file
with open(output_file_path, 'r') as file:
    # Read the file content
    content = file.read()

# Split the content into words
words = content.split()

# Count word occurrences
word_counts = text_processing.count_word_occurrences(words)

# Print the five most common words and their occurrences
text_processing.print_common_words(word_counts, 5)

# Print the five least common words and their occurrences
text_processing.print_least_common_words(word_counts, 5)
# Out:
# 5 most common words:
# the: 14
# and: 9
# i: 9
# of: 8
# is: 7
# 5 least common words:
# land: 1
# look: 1
# at: 1
# crowds: 1
# watergazers: 1

# %% [markdown]
# * add r before file string (otherwise \\n in line 14 is written as linefeed).
# * import string in line 1 of module.

# %% [markdown]
# ### Copilot version

# %%
# Copilot version
# FILENAME: word_processing.py

import string

def clean_line(line):
    line = line.lower()
    line = line.translate(str.maketrans('', '', string.punctuation))
    return line

def write_words_to_file(words, output_file):
    for word in words:
        output_file.write(word + '\n')

def count_word_occurrences(words):
    word_counts = {}
    for word in words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1
    return word_counts

def print_common_words(word_counts, n):
    sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)
    print(f"{n} most common words:")
    for word, count in sorted_word_counts[:n]:
        print(f"{word}: {count}")

def print_least_common_words(word_counts, n):
    sorted_word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)
    print(f"{n} least common words:")
    for word, count in sorted_word_counts[-n:]:
        print(f"{word}: {count}")

def process_file(input_file_path, output_file_path):
    with open(input_file_path, 'r') as input_file:
        with open(output_file_path, 'w') as output_file:
            for line in input_file:
                cleaned_line = clean_line(line)
                words = cleaned_line.split()
                write_words_to_file(words, output_file)

# %%
# FILENAME: main.py

import word_processing

input_file_path = "path_to_input_file"
output_file_path = "path_to_output_file"

# Process the file
word_processing.process_file(input_file_path, output_file_path)

# Count word occurrences
with open(output_file_path, 'r') as output_file:
    words = output_file.read().split()
    word_counts = word_processing.count_word_occurrences(words)

# Print common and least common words
word_processing.print_common_words(word_counts, 10)
word_processing.print_least_common_words(word_counts, 10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 9
#       6 output_file_path = "path_to_output_file"
#       8 # Process the file
# ----> 9 word_processing.process_file(input_file_path, output_file_path)
#      11 # Count word occurrences
#      12 with open(output_file_path, 'r') as output_file:
#
# File ~/2025/qpb4e/code/Chapter 10/word_processing.py:35, in process_file(input_file_path, output_file_path)
#      34 def process_file(input_file_path, output_file_path):
# ---> 35     with open(input_file_path, 'r') as input_file:
#      36         with open(output_file_path, 'w') as output_file:
#      37             for line in input_file:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_input_file'

# %%
# FILENAME: main.py

import word_processing

input_file_path = "moby_01.txt"
output_file_path = "moby_01_clean.txt"

# Process the file
word_processing.process_file(input_file_path, output_file_path)

# Count word occurrences
with open(output_file_path, 'r') as output_file:
    words = output_file.read().split()
    word_counts = word_processing.count_word_occurrences(words)

# Print common and least common words
word_processing.print_common_words(word_counts, 10)
word_processing.print_least_common_words(word_counts, 10)
# Out:
# 10 most common words:
# the: 14
# and: 9
# i: 9
# of: 8
# is: 7
# a: 6
# it: 6
# me: 5
# to: 5
# in: 4
# 10 least common words:
# hours: 1
# previous: 1
# were: 1
# out: 1
# sight: 1
# land: 1
# look: 1
# at: 1
# crowds: 1
# watergazers: 1
